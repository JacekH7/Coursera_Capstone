# %% [markdown]
# ## Coursera Capstone Project Code

# %% [markdown]
# 1. Import all necessary libraries

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
import geopy.distance
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans
from sklearn.cluster import AgglomerativeClustering
from sklearn.cluster import AffinityPropagation
from sklearn.cluster import MeanShift, estimate_bandwidth

from sklearn import metrics

import folium # map rendering library

import requests

# %% [markdown]
# 2. Get center locations for Toronto, Toronto Downtown and Toronto Midtown

# %%
address = 'Toronto, Ontario'

geolocator = Nominatim(user_agent='jacekh7@gmail.com')
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print (location, latitude, longitude)

Toronto_loc = (latitude,longitude)

#### use 2.4km radius of downtown for stations
address = 'Downtown Toronto, Ontario'

geolocator = Nominatim(user_agent='jacekh7@gmail.com')
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print (location, latitude, longitude)

Downtown_loc = (latitude,longitude)

#### 3.9km radius for stations
address = 'Midtown Toronto, Ontario'

geolocator = Nominatim(user_agent='jacekh7@gmail.com')
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print (location, latitude, longitude)

Midtown_loc = (latitude,longitude)
# Out:
# Toronto, Ontario, Canada 43.653963 -79.387207
# Downtown Jewellery Mart, 257, Yonge Street, Downtown Yonge, Old Toronto, Toronto, Ontario, M5B 1N8, Canada 43.655115 -79.380219
# Minto Midtown - Quantum, Anne Johnston Courtyard, Yonge & Eglinton, Old Toronto, Toronto, Ontario, M4S 3H8, Canada 43.7051999 -79.3974155214733

# %% [markdown]
# 3. Pull list of metro stations and their locations from Foursquare

# %%
CLIENT_ID = 'DXTH5G523ZNYLLR345NFCITN2RDU4WWUFOCDXFK4RGNVIHON' # your Foursquare ID
CLIENT_SECRET = 'Y3GQRX4CQF53S02J45MCCVUT01A0AZ2GYAESM2SNMZNFO0S1' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)

    
stations_list=[]
stations_list2=[]
LIMIT = 100
metro_category = '4bf58dd8d48988d1fd931735'  # results to contain only metro stations
radius=20000

url = 'https://api.foursquare.com/v2/venues/search?&client_id={}&client_secret={}&v={}&ll={},{}&categoryId={}&radius={}&limit={}'.format(
        CLIENT_ID, 
        CLIENT_SECRET, 
        VERSION, 
        latitude, 
        longitude, 
        metro_category,
        radius, 
        LIMIT)

# make the GET request
results = requests.get(url).json()['response']['venues']


for v in results:
    print('name:', v['name'])
    print('lat lon: ', v['location']['lat'],', ',v['location']['lng'])
    stations_list2.append((v['name'], v['location']['lat'], v['location']['lng']))
# Out:
# Your credentails:
# CLIENT_ID: DXTH5G523ZNYLLR345NFCITN2RDU4WWUFOCDXFK4RGNVIHON
# CLIENT_SECRET:Y3GQRX4CQF53S02J45MCCVUT01A0AZ2GYAESM2SNMZNFO0S1
# name: Eglinton Subway Station
# lat lon:  43.706715975800265 ,  -79.39829838965822
# name: St. George Subway Station
# lat lon:  43.66867511169067 ,  -79.39766618073506
# name: Bloor-Yonge Subway Station
# lat lon:  43.67075854014261 ,  -79.38576936721802
# name: Kennedy Subway/RT Station
# lat lon:  43.73291798585667 ,  -79.26498413085938
# name: Osgoode Subway Station
# lat lon:  43.65087700047692 ,  -79.38682418315692
# name: Glencairn Subway Station
# lat lon:  43.708872397351165 ,  -79.44080107629773
# name: Main Street Subway Station
# lat lon:  43.68910856344984 ,  -79.30166156422199
# name: Lawrence West Subway Station
# lat lon:  43.715643052756256 ,  -79.44405919225414
# name: Lawrence Subway Station
# lat lon:  43.725847437997636 ,  -79.4026780128479
# name: Victoria Park Subway Station
# lat lon:  43.69488264493771 ,  -79.28873509168625
# name: Union Subway Station
# lat lon:  43.64560188525978 ,  -79.37979340553284
# name: Don Mills Subway Station
# name: Museum Subway Station
# lat lon:  43.66704896485094 ,  -79.3937087059021

# %% [markdown]
# 4. Classify each station's neighbourhood: Downtown, Midtown or Suburb

# %%
for v in stations_list2:
    #print(v[0])
    lat_lon = (v[1],v[2])
    if geopy.distance.vincenty(Downtown_loc, lat_lon).km < 2.4:
        print(v[0], ', Downtown')
        print(geopy.distance.vincenty(Downtown_loc, lat_lon).km)
        v += ('Downtown',)
 #       print('Downtown')
    elif geopy.distance.vincenty(Midtown_loc, lat_lon).km < 3.9:
        print(v[0], ', Midtown')
        print(geopy.distance.vincenty(Midtown_loc, lat_lon).km)
        v += ('Midtown',)
 #       print('Midtown')
    else:
        print(v[0], ', Suburb')
        v += ('Suburb',)
    stations_list.append(v)
# Out:
# Eglinton Subway Station , Midtown
# 0.18286005214417128
# St. George Subway Station , Downtown
# 2.0616340604955594
# Bloor-Yonge Subway Station , Downtown
# 1.7948163166579858
# Kennedy Subway/RT Station , Suburb
# Osgoode Subway Station , Downtown
# 0.7110890611525704
# Glencairn Subway Station , Midtown
# 3.5205927554788667
# Main Street Subway Station , Suburb
# Lawrence West Subway Station , Suburb
# Lawrence Subway Station , Midtown
# 2.3329505890739433
# Victoria Park Subway Station , Suburb
# Union Subway Station , Downtown
# 1.0575161227964835
# Don Mills Subway Station , Suburb
# Pioneer Village Subway Station , Suburb
# Sherbourne Subway Station , Downtown
# 1.9303187616650037
# Wellesley Subway Station , Downtown
# 1.1420635105669354
# Bathurst Subway Station , Suburb
# York University Subway Station , Suburb
# Spadina Subway Station , Downtown
# 2.3217321106792745
# Keele Subway Station , Suburb
# Union Station , Downtown
# 1.1057874530801972
# Pape Subway Station , Suburb
# St Andrew Subway Station , Downtown
# 0.9002317428855361
# St Clair Subway Station , Midtown
# 1.9238399289380592
# Kipling Subway Station , Suburb
# Davisville Subway Station , Midtown
# 0.8165766608509083
# Dufferin Subway Station , Suburb
# Broadview Subway Station , Suburb
# Islington Subway Station , Suburb
# Eglinton West Subway Station , Midtown
# 3.2054397694289674
# Rosedale Subway Station , Midtown
# 3.2378591877207388
# Donlands Subway Station , Suburb
# Runnymede Subway Station , Suburb
# Greenwood Subway Station , Suburb
# Lansdowne Subway Station , Suburb
# Yorkdale Subway Station , Suburb
# Vaughan Metropolitan Centre Subway Station , Suburb
# Finch Subway Station , Suburb
# Christie Subway Station , Suburb
# High Park Subway Station , Suburb
# Royal York Subway Station , Suburb
# Queen Subway Station , Downtown
# 0.31569619682814415
# Sheppard-Yonge Subway Station , Suburb
# Finch West Subway Station , Suburb
# Coxwell Subway Station , Suburb
# Wilson Subway Station , Suburb
# Ossington Subway Station , Suburb
# Dundas West Subway Station , Suburb
# Queen's Park Subway Station , Downtown
# 0.9762115298203722
# St Clair West Subway Station , Midtown
# 2.771814499744535
# Museum Subway Station , Downtown
# 1.7152402011212236

# %% [markdown]
# Create data frame with stations, location details and category

# %%
stat_df = pd.DataFrame(stations_list, columns=['Station Name','lat', 'lng', 'Station location'])

# %% [markdown]
# 5. Show stations on the map

# %%
map_toronto = folium.Map(location=[Toronto_loc[0], Toronto_loc[1]], zoom_start=9)

for name, lat, lng, loc in zip(stat_df['Station Name'], stat_df['lat'], stat_df['lng'], stat_df['Station location']):
    name = folium.Popup(name, parse_html=True)
    if loc=='Downtown':
        folium.CircleMarker(
            [float(lat), float(lng)],
            radius=5,
            popup=name,
            color='blue',
            fill=True,
            fill_color='#3186cc',
            fill_opacity=0.5,
            parse_html=False).add_to(map_toronto)
    elif loc == 'Midtown':
        folium.CircleMarker(
            [float(lat), float(lng)],
            radius=5,
            popup=name,
            color='red',
            fill=True,
            fill_color='#3186cc',
            fill_opacity=0.5,
            parse_html=False).add_to(map_toronto)
    else:
         folium.CircleMarker(
            [float(lat), float(lng)],
            radius=5,
            popup=name,
            color='yellow',
            fill=True,
            fill_color='#3186cc',
            fill_opacity=0.5,
            parse_html=False).add_to(map_toronto)

# %%
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# 6. Collect list of venues 400m around each station

# %%
venues_list=[]
LIMIT = 100
radius=400
for name, lat, lng, loc in zip(stat_df['Station Name'], stat_df['lat'], stat_df['lng'], stat_df['Station location']):
    print(name)
   
        # create the API request URL
    url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
        CLIENT_ID, 
        CLIENT_SECRET, 
        VERSION, 
        lat, 
        lng, 
        radius, 
        LIMIT)
            
        # make the GET request
    results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
    venues_list.append([(
        name, 
        lat, 
        lng, 
        loc,
        v['venue']['name'], 
        v['venue']['location']['lat'], 
        v['venue']['location']['lng'],  
        v['venue']['categories'][0]['name']) for v in results])


    
nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
nearby_venues.columns = ['Station Name', 
                         'Station Latitude', 
                         'Station Longitude', 
                         'Station Location',
                         'Venue', 
                         'Venue Latitude', 
                         'Venue Longitude', 
                         'Venue Category']
# Out:
# Eglinton Subway Station
# St. George Subway Station
# Bloor-Yonge Subway Station
# Kennedy Subway/RT Station
# Osgoode Subway Station
# Glencairn Subway Station
# Main Street Subway Station
# Lawrence West Subway Station
# Lawrence Subway Station
# Victoria Park Subway Station
# Union Subway Station
# Don Mills Subway Station
# Pioneer Village Subway Station
# Sherbourne Subway Station
# Wellesley Subway Station
# Bathurst Subway Station
# York University Subway Station
# Spadina Subway Station
# Keele Subway Station
# Union Station
# Pape Subway Station
# St Andrew Subway Station
# St Clair Subway Station
# Kipling Subway Station
# Davisville Subway Station
# Dufferin Subway Station
# Broadview Subway Station
# Islington Subway Station
# Eglinton West Subway Station
# Rosedale Subway Station
# Donlands Subway Station
# Runnymede Subway Station
# Greenwood Subway Station
# Lansdowne Subway Station
# Yorkdale Subway Station
# Vaughan Metropolitan Centre Subway Station
# Finch Subway Station
# Christie Subway Station
# High Park Subway Station
# Royal York Subway Station
# Queen Subway Station
# Sheppard-Yonge Subway Station
# Finch West Subway Station
# Coxwell Subway Station
# Wilson Subway Station
# Ossington Subway Station
# Dundas West Subway Station
# Queen's Park Subway Station
# St Clair West Subway Station
# Museum Subway Station

# %% [markdown]
# 7. Remove venues that are not in scope from the list

# %%
df=nearby_venues[~nearby_venues['Venue Category'].isin(['Beach',
                 'Bridge',
                 'Castle',
                 'City',
                 'Community Center',
                 'Lake',
                 'Historic Site',
                 'Monument / Landmark',
                 'Park',
                 'Neighborhood',
                 'Scenic Lookout',
                 'Town',
                 'Trail',
                 'Plaza',
                 'Baseball Field',
                 'Bookstore',
                 'Train Station',
                 'Electronics Store',
                 'Hotel',
                 'Library',
                 'Tailor Shop',
                 'Hostel',
                 'Bus Station',
                 'Bus Stop',
                 'Bus Line',
                 'Light Rail Station',
                 'Clothing Store',
                 'Art Galery',
                 'Art Museum',
                 'Antique Shop',
                 'Furniture / Home Store',
                 'Metro Station',
                 'Intersection',
                 'Arts & Crafts Store',
                 'Hobby Shop',
                 'Track',
                 'Playground'])]

# %% [markdown]
# 8. Code and group venues of the same type, inlcude Station Location category as one of attributes

# %%
df_onehot = pd.get_dummies(data = df, columns=['Venue Category','Station Location'], prefix="", prefix_sep="")

df_onehot['Station Name'] = df['Station Name']
df_onehot.drop(['Station Latitude','Station Longitude', 'Venue', 'Venue Latitude','Venue Longitude'], axis=1, inplace=True)

df_grouped = df_onehot.groupby('Station Name').mean().reset_index()

# %% [markdown]
# 9. List top venues

# %%
num_top_venues = 6   #Station Location category is aloways on top, so 6 overall

for hood in df_grouped['Station Name']:
    print("----"+hood+"----")
    temp = df_grouped[df_grouped['Station Name'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')

def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

num_top_venues = 11   # 11 Top venues as 1st is always Station Location

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Station Name']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))
# Out:
# ----Bathurst Subway Station----
#                          venue  freq
# 0                       Suburb  1.00
# 1            Korean Restaurant  0.11
# 2               Ice Cream Shop  0.04
# 3  Eastern European Restaurant  0.04
# 4                Grocery Store  0.04
# 5             Sushi Restaurant  0.04
#
#
# ----Bloor-Yonge Subway Station----
#                  venue  freq
# 0             Downtown  1.00
# 1          Coffee Shop  0.10
# 2                 Café  0.08
# 3  Japanese Restaurant  0.06
# 4           Restaurant  0.04
# 5     Sushi Restaurant  0.04
#
#
# ----Broadview Subway Station----
#             venue  freq
# 0          Suburb  1.00
# 1             Pub  0.07
# 2             Spa  0.07
# 3     Pizza Place  0.04
# 4  Sandwich Place  0.04
# 5             Gym  0.04
#
#
# ----Christie Subway Station----
#                 venue  freq
# 0              Suburb  1.00
# 1   Korean Restaurant  0.30
# 2         Coffee Shop  0.07
# 3   Indian Restaurant  0.07
# 4       Grocery Store  0.04
# 5  Mexican Restaurant  0.04
#
#
# ----Coxwell Subway Station----
#                venue  freq
# 0             Suburb  1.00
# 1          Gastropub  0.13
# 2     Breakfast Spot  0.07
# 3  French Restaurant  0.07
# 4      Bowling Alley  0.07
# 5        Coffee Shop  0.07
#
#
# ----Davisville Subway Station----
#                venue  freq
# 0            Midtown  1.00
# 1        Coffee Shop  0.10
# 2   Sushi Restaurant  0.10
# 3                Pub  0.07
# 4     Sandwich Place  0.07
# 5  Convenience Store  0.07
#
#
# ----Don Mills Subway Station----
#            venue  freq
# 0         Suburb  1.00
# 1  Women's Store  0.09
# 2    Coffee Shop  0.09
# 3         Bakery  0.06
# 4     Restaurant  0.03
# 5    Candy Store  0.03
#
#
# ----Donlands Subway Station----
#          venue  freq
# 0       Suburb  1.00
# 1  Pizza Place  0.17
# 2         Café  0.13
# 3  Coffee Shop  0.13
# 4     Beer Bar  0.04
# 5    Gastropub  0.04
#
#
# ----Dufferin Subway Station----
#           venue  freq
# 0        Suburb  1.00
# 1          Café  0.13
# 2           Bar  0.13
# 3        Bakery  0.13
# 4    Beer Store  0.06
# 5  Cocktail Bar  0.06
#
#
# ----Dundas West Subway Station----
#              venue  freq
# 0           Suburb  1.00
# 1      Coffee Shop  0.12
# 2      Pizza Place  0.09
# 3              Bar  0.09
# 4              Pub  0.06
# 5  Thai Restaurant  0.06
#
#
# ----Eglinton Subway Station----
#                   venue  freq
# 0               Midtown  1.00
# 1           Coffee Shop  0.14
# 2  Fast Food Restaurant  0.08
# 3    Italian Restaurant  0.04
# 4                   Pub  0.04
# 5          Liquor Store  0.03
#
#
# ----Eglinton West Subway Station----
#                   venue  freq
# 0               Midtown   1.0
# 1           Coffee Shop   0.2
# 2           Record Shop   0.1
# 3                Bakery   0.1
# 4  Caribbean Restaurant   0.1
# 5    Mexican Restaurant   0.1
#
#
# ----Finch Subway Station----
#                    venue  freq
# 0                 Suburb  1.00
# 1      Korean Restaurant  0.17
# 2            Coffee Shop  0.11
# 3                   Café  0.09
# 4  Vietnamese Restaurant  0.06
# 5           Dessert Shop  0.06
#
#
# ----Finch West Subway Station----
#               venue  freq
# 0            Suburb  1.00
# 1              Bank  0.14
# 2  Sushi Restaurant  0.14
# 3       Pizza Place  0.14
# 4    Massage Studio  0.14
# 5       Coffee Shop  0.14
#
#
# ----Glencairn Subway Station----
#                  venue  freq
# 0              Midtown  1.00
# 1  Japanese Restaurant  0.25
# 2                  Pub  0.25
# 3               Arcade  0.25
# 4               Bakery  0.25
# 5            Pet Store  0.00
#
#
# ----Greenwood Subway Station----
#                   venue  freq
# 0                Suburb  1.00
# 1                  Café  0.23
# 2  Ethiopian Restaurant  0.09
# 3           Coffee Shop  0.09
# 4              Beer Bar  0.05
# 5          Liquor Store  0.05
#
#
# ----High Park Subway Station----
#                 venue  freq
# 0              Suburb  1.00
# 1   Convenience Store  0.17
# 2           Pet Store  0.17
# 3  Mexican Restaurant  0.08
# 4      Shipping Store  0.08
# 5         Coffee Shop  0.08
#
#
# ----Islington Subway Station----
#               venue  freq
# 0            Suburb  1.00
# 1       Coffee Shop  0.12
# 2  Sushi Restaurant  0.08
# 3    Sandwich Place  0.08
# 4        Restaurant  0.08
# 5               Pub  0.08
#
#
# ----Keele Subway Station----
#                venue  freq
# 0             Suburb  1.00
# 1                Bar  0.15
# 2        Pizza Place  0.11
# 3  Convenience Store  0.11
# 4    Thai Restaurant  0.07
# 5     Sandwich Place  0.07
#
#
# ----Kennedy Subway/RT Station----
#                 venue  freq
# 0              Suburb  1.00
# 1         Coffee Shop  0.22
# 2        Hockey Arena  0.11
# 3      Sandwich Place  0.11
# 4   Convenience Store  0.11
# 5  Chinese Restaurant  0.11
#
#
# ----Kipling Subway Station----
#            venue  freq
# 0         Suburb  1.00
# 1    Coffee Shop  0.23
# 2  Grocery Store  0.15
# 3     Restaurant  0.08
# 4   Cupcake Shop  0.08
# 5       Pharmacy  0.08
#
#
# ----Lansdowne Subway Station----
#                   venue  freq
# 0                Suburb  1.00
# 1                   Bar  0.15
# 2                  Café  0.12
# 3  Caribbean Restaurant  0.08
# 4                Bakery  0.08
# 5        Ice Cream Shop  0.04
#
#
# ----Lawrence Subway Station----
#          venue  freq
# 0      Midtown  1.00
# 1  Coffee Shop  0.15
# 2         Bank  0.10
# 3  Pizza Place  0.10
# 4          Pub  0.05
# 5    Gastropub  0.05
#
#
# ----Lawrence West Subway Station----
#                   venue  freq
# 0                Suburb  1.00
# 1  Fast Food Restaurant  0.22
# 2            Restaurant  0.22
# 3           Coffee Shop  0.22
# 4             Pet Store  0.11
# 5                   Gym  0.11
#
#
# ----Main Street Subway Station----
#                   venue  freq
# 0                Suburb  1.00
# 1         Grocery Store  0.15
# 2              Pharmacy  0.10
# 3  Fast Food Restaurant  0.05
# 4    Chinese Restaurant  0.05
# 5   Fried Chicken Joint  0.05
#
#
# ----Museum Subway Station----
#                 venue  freq
# 0            Downtown  1.00
# 1         Coffee Shop  0.12
# 2            Boutique  0.07
# 3  Italian Restaurant  0.07
# 4      Cosmetics Shop  0.07
# 5          Restaurant  0.05
#
#
# ----Osgoode Subway Station----
#              venue  freq
# 0         Downtown  1.00
# 1             Café  0.08
# 2       Steakhouse  0.08
# 3      Coffee Shop  0.06
# 4  Thai Restaurant  0.06
# 5              Bar  0.04
#
#
# ----Ossington Subway Station----
#                venue  freq
# 0             Suburb  1.00
# 1                Bar  0.09
# 2               Café  0.09
# 3       Cocktail Bar  0.07
# 4                Pub  0.04
# 5  Indian Restaurant  0.04
#
#
# ----Pape Subway Station----
#               venue  freq
# 0            Suburb  1.00
# 1  Greek Restaurant  0.17
# 2       Coffee Shop  0.13
# 3       Pizza Place  0.09
# 4    Ice Cream Shop  0.04
# 5               Pub  0.04
#
#
# ----Pioneer Village Subway Station----
#                      venue  freq
# 0                   Suburb   1.0
# 1           Shop & Service   0.5
# 2       Athletics & Sports   0.5
# 3  New American Restaurant   0.0
# 4                Nightclub   0.0
# 5             Noodle House   0.0
#
#
# ----Queen Subway Station----
#                  venue  freq
# 0             Downtown  1.00
# 1          Coffee Shop  0.11
# 2   Italian Restaurant  0.05
# 3       Cosmetics Shop  0.04
# 4  American Restaurant  0.04
# 5           Restaurant  0.04
#
#
# ----Queen's Park Subway Station----
#                 venue  freq
# 0            Downtown  1.00
# 1         Coffee Shop  0.48
# 2                Café  0.09
# 3  Italian Restaurant  0.06
# 4   Indian Restaurant  0.06
# 5      Sandwich Place  0.06
#
#
# ----Rosedale Subway Station----
#                 venue  freq
# 0             Midtown  1.00
# 1  Italian Restaurant  0.11
# 2                Café  0.07
# 3         Yoga Studio  0.07
# 4   French Restaurant  0.07
# 5         Coffee Shop  0.07
#
#
# ----Royal York Subway Station----
#               venue  freq
# 0            Suburb  1.00
# 1       Coffee Shop  0.09
# 2    Breakfast Spot  0.06
# 3  Sushi Restaurant  0.06
# 4      Dessert Shop  0.06
# 5               Pub  0.06
#
#
# ----Runnymede Subway Station----
#                venue  freq
# 0             Suburb  1.00
# 1        Coffee Shop  0.15
# 2             Bakery  0.09
# 3               Café  0.09
# 4        Pizza Place  0.06
# 5  Indian Restaurant  0.03
#
#
# ----Sheppard-Yonge Subway Station----
#                   venue  freq
# 0                Suburb  1.00
# 1   Japanese Restaurant  0.10
# 2  Fast Food Restaurant  0.08
# 3           Pizza Place  0.08
# 4     Korean Restaurant  0.05
# 5                  Café  0.05
#
#
# ----Sherbourne Subway Station----
#                  venue  freq
# 0             Downtown  1.00
# 1       Sandwich Place  0.13
# 2          Coffee Shop  0.13
# 3  Japanese Restaurant  0.07
# 4  Filipino Restaurant  0.07
# 5             Pharmacy  0.07
#
#
# ----Spadina Subway Station----
#               venue  freq
# 0          Downtown  1.00
# 1       Coffee Shop  0.07
# 2       Pizza Place  0.05
# 3  Sushi Restaurant  0.04
# 4        Restaurant  0.04
# 5               Pub  0.04
#
#
# ----St Andrew Subway Station----
#                  venue  freq
# 0             Downtown  1.00
# 1          Coffee Shop  0.13
# 2           Steakhouse  0.06
# 3                 Café  0.06
# 4  American Restaurant  0.03
# 5                  Gym  0.03
#
#
# ----St Clair Subway Station----
#                 venue  freq
# 0             Midtown  1.00
# 1         Coffee Shop  0.11
# 2  Italian Restaurant  0.09
# 3    Sushi Restaurant  0.06
# 4                Café  0.06
# 5      Sandwich Place  0.06
#
#
# ----St Clair West Subway Station----
#                venue  freq
# 0            Midtown  1.00
# 1     Ice Cream Shop  0.11
# 2  Food & Drink Shop  0.11
# 3        Pizza Place  0.11
# 4               Bank  0.06
# 5    Thai Restaurant  0.06
#
#
# ----St. George Subway Station----
#             venue  freq
# 0        Downtown  1.00
# 1     Coffee Shop  0.13
# 2      Restaurant  0.06
# 3  Cosmetics Shop  0.05
# 4  Sandwich Place  0.05
# 5             Gym  0.03
#
#
# ----Union Station----
#                 venue  freq
# 0            Downtown  1.00
# 1         Coffee Shop  0.19
# 2          Restaurant  0.07
# 3                Café  0.05
# 4  Italian Restaurant  0.04
# 5          Sports Bar  0.03
#
#
# ----Union Subway Station----
#            venue  freq
# 0       Downtown  1.00
# 1    Coffee Shop  0.19
# 2     Restaurant  0.07
# 3           Café  0.06
# 4  Deli / Bodega  0.04
# 5         Bakery  0.03
#
#
# ----Vaughan Metropolitan Centre Subway Station----
#                   venue  freq
# 0                Suburb  1.00
# 1                  Café  0.25
# 2    Italian Restaurant  0.12
# 3        Sandwich Place  0.12
# 4  Fast Food Restaurant  0.12
# 5         Shopping Mall  0.12
#
#
# ----Victoria Park Subway Station----
#                venue  freq
# 0             Suburb  1.00
# 1        Golf Course  0.33
# 2  Convenience Store  0.33
# 3               Bank  0.33
# 4           Pharmacy  0.00
# 5          Nightclub  0.00
#
#
# ----Wellesley Subway Station----
#                  venue  freq
# 0             Downtown  1.00
# 1  Japanese Restaurant  0.08
# 2              Gay Bar  0.08
# 3         Burger Joint  0.06
# 4          Coffee Shop  0.06
# 5            Nightclub  0.04
#
#
# ----Wilson Subway Station----
#                   venue  freq
# 0                Suburb  1.00
# 1  Gym / Fitness Center  0.25
# 2  Fast Food Restaurant  0.25
# 3           Coffee Shop  0.25
# 4         Jewelry Store  0.25
# 5     Korean Restaurant  0.00
#
#
# ----York University Subway Station----
#                   venue  freq
# 0                Suburb  1.00
# 1           Coffee Shop  0.14
# 2            Restaurant  0.10
# 3  Fast Food Restaurant  0.10
# 4                  Café  0.10
# 5          Burger Joint  0.05
#
#
# ----Yorkdale Subway Station----
#                  venue  freq
# 0               Suburb  1.00
# 1          Coffee Shop  0.10
# 2       Cosmetics Shop  0.08
# 3     Toy / Game Store  0.05
# 4  Sporting Goods Shop  0.05
# 5       Sandwich Place  0.05

# %%
# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Station Name'] = df_grouped['Station Name']

for ind in np.arange(df_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(df_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted
# Out:
#                
# 23            Restaurant  Fast Food Restaurant                Coffee Shop
# 24         Grocery Store              Pharmacy                       Café
# 25           Coffee Shop    Italian Restaurant             Cosmetics Shop
# 26                  Café            Steakhouse            Thai Restaurant
# 27                  Café                   Bar               Cocktail Bar
# 28      Greek Restaurant           Coffee Shop                Pizza Place
# 29    Athletics & Sports        Shop & Service         Falafel Restaurant
# 30           Coffee Shop    Italian Restaurant        American Restaurant
# 31           Coffee Shop                  Café         Italian Restaurant
# 32    Italian Restaurant           Coffee Shop                Yoga Studio
# 33           Coffee Shop      Sushi Restaurant             Breakfast Spot
# 34           Coffee Shop                Bakery                       Café
# 35   Japanese Restaurant  Fast Food Restaurant                Pizza Place
# 36           Coffee Shop        Sandwich Place          Food & Drink Shop
# 37           Coffee Shop           Pizza Place  Middle Eastern Restaurant
# 38           Coffee Shop                  Café                 Steakhouse
# 39           Coffee Shop    Italian Restaurant                       Café
# 40     Food & Drink Shop           Pizza Place             Ice Cream Shop
# 41           Coffee Shop            Restaurant             Cosmetics Shop
# 42           Coffee Shop            Restaurant                       Café
# 43           Coffee Shop            Restaurant                       Café
# 44                  Café         Shopping Mall              Big Box Store
# 45     Convenience Store           Golf Course                       Bank
# 46               Gay Bar   Japanese Restaurant                Coffee Shop
# 47           Coffee Shop  Fast Food Restaurant       Gym / Fitness Center
# 48           Coffee Shop  Fast Food Restaurant                 Restaurant
# 49           Coffee Shop        Cosmetics Shop           Toy / Game Store
#
#    5th Most Common Venue          6th Most Common Venue  \
# 0            Pizza Place             Mexican Restaurant
# 1            Yoga Studio               Sushi Restaurant
# 2            Coffee Shop                    Pizza Place
# 3         Ice Cream Shop             Mexican Restaurant
# 4         Breakfast Spot                  Bowling Alley
# 5      Convenience Store                 Sandwich Place
# 6           Burger Joint                       Boutique
# 7           Liquor Store                          Diner
# 8           Cocktail Bar                     Beer Store
# 9        Thai Restaurant                            Pub
# 10    Italian Restaurant                    Salad Place
# 11           Yoga Studio                    Pizza Place
# 12          Dessert Shop          Vietnamese Restaurant
# 13           Coffee Shop                           Bank
# 14                Bakery             Falafel Restaurant
# 15                   Bar            Rental Car Location
# 16           Coffee Shop                 Shipping Store
# 17            Restaurant                 Sandwich Place
# 18       Thai Restaurant                 Sandwich Place
# 19                  Bank                 Discount Store
# 20                  Café               Sushi Restaurant
# 21  Caribbean Restaurant                 Sandwich Place
# 22    Italian Restaurant               Sushi Restaurant
# 23             Pet Store                            Gym
# 24  Gym / Fitness Center             Mexican Restaurant
# 25              Boutique                     Restaurant
# 26           Coffee Shop  Vegetarian / Vegan Restaurant
# 27  Ethiopian Restaurant                            Pub
# 28         Grocery Store                            Pub
# 29   Fried Chicken Joint              French Restaurant
# 30        Cosmetics Shop                     Restaurant
# 31     Indian Restaurant                 Sandwich Place
# 32     French Restaurant                           Café
# 33          Dessert Shop                            Pub
# 34           Pizza Place               Greek Restaurant
# 35        Sandwich Place                           Café
# 36   Filipino Restaurant                           Bank
# 37       Thai Restaurant                            Pub
# 38    Italian Restaurant                            Gym
# 12                Salad Place                 Restaurant
# 13                    Dog Run                 Donut Shop
# 14                 Food Truck                 Food Court
# 15  Middle Eastern Restaurant         Mexican Restaurant
# 16         Mexican Restaurant                        Gym
# 17                 Donut Shop       Fast Food Restaurant
# 18                  Pet Store               Dance Studio
# 19         Chinese Restaurant       Fast Food Restaurant
# 20               Burger Joint                 Restaurant
# 21                  Gastropub                  Gift Shop
# 22                       Pool             Ice Cream Shop
# 23                Event Space                 Food Truck
# 24        Fried Chicken Joint          Fish & Chips Shop
# 25                     Office            College Theater
# 26        Japanese Restaurant                Pizza Place
# 27                     Bakery             Breakfast Spot
# 28                        Gym           Ramen Restaurant
# 29          Food & Drink Shop                Flower Shop
# 30                 Food Court        Japanese Restaurant
# 31                  Gastropub         Chinese Restaurant
# 32             Sandwich Place         Salon / Barbershop
# 33                     Bakery                Pizza Place
# 34               Liquor Store  Latin American Restaurant
# 35                 Restaurant          Korean Restaurant
# 36                        Bar                   Pharmacy
# 37            Bubble Tea Shop             Ice Cream Shop
# 38                    Theater                 Restaurant
# 39                        Gym            Thai Restaurant
# 40             Sandwich Place            Thai Restaurant
# 41         Italian Restaurant        American Restaurant
# 42                       Bank                Salad Place
# 43             Breakfast Spot        Sporting Goods Shop
# 44      Vietnamese Restaurant        Fried Chicken Joint
# 45          French Restaurant                 Food Truck
# 46              Burrito Place       Ethiopian Restaurant
# 47          French Restaurant                 Food Truck
# 48        Fried Chicken Joint         Falafel Restaurant
# 49             Sandwich Place        Sporting Goods Shop
#
#          11th Most Common Venue
# 0                Cosmetics Shop
# 1                        Lounge
# 2             Fish & Chips Shop
# 3                  Cocktail Bar
# 4                Sandwich Place
# 5                   Flower Shop
# 6            Frozen Yogurt Shop
# 7                  Burger Joint
# 8                     Gift Shop
# 9            Chinese Restaurant
# 10                  Supermarket
# 11          Filipino Restaurant
# 12                Hot Dog Joint
# 13          Fried Chicken Joint
# 14            Food & Drink Shop
# 15                 Liquor Store
# 16                          Pub
# 17  Eastern European Restaurant
# 18                          Pub
# 19          Filipino Restaurant
# 20                 Cupcake Shop
# 21                Grocery Store
# 22               Cosmetics Shop
# 23                   Food Court
# 24         Fast Food Restaurant
# 25                          Pub
# 26             Asian Restaurant
# 27            Convenience Store
# 28        Portuguese Restaurant
# 29            Fish & Chips Shop
# 30                     Tea Room
# 31                Burrito Place
# 32               Cosmetics Shop
# 33                    Pool Hall
# 34            Indian Restaurant
# 35           Frozen Yogurt Shop
# 36                Smoothie Shop
# 37             Greek Restaurant
# 38                  Pizza Place
# 39                   Bagel Shop
# 40                Grocery Store
# 41                          Gym
# 42          Sporting Goods Shop
# 43                  Salad Place
# 44                   Food Truck
# 45                   Food Court
# 46               Breakfast Spot
# 47                   Food Court
# 48                    Drugstore
# 49            Accessories Store

# %% [markdown]
# 10. Cluster locations using K-means 5 clusters

# %%
# set number of clusters
kclusters = 5

df_grouped_clustering = df_grouped.drop('Station Name', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(df_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10] 

k_labels = kmeans.labels_

df_merged = stat_df.copy()

# add clustering labels
df_merged['Cluster Labels'] = kmeans.labels_

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
df_merged = df_merged.join(neighborhoods_venues_sorted.set_index('Station Name'), on='Station Name')

df_merged.head() # check the last columns!
# Out:
#                  Station Name        lat        lng Station location  \
# 0     Eglinton Subway Station  43.706716 -79.398298          Midtown
# 1   St. George Subway Station  43.668675 -79.397666         Downtown
# 2  Bloor-Yonge Subway Station  43.670759 -79.385769         Downtown
# 3   Kennedy Subway/RT Station  43.732918 -79.264984           Suburb
# 4      Osgoode Subway Station  43.650877 -79.386824         Downtown
#
#    Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 0               0               Midtown           Coffee Shop
# 1               1              Downtown           Coffee Shop
# 2               0              Downtown           Coffee Shop
# 3               0                Suburb           Coffee Shop
# 4               0              Downtown                  Café
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 0  Fast Food Restaurant                   Pub    Italian Restaurant
# 1            Restaurant        Cosmetics Shop        Sandwich Place
# 2                  Café   Japanese Restaurant           Yoga Studio
# 3        Sandwich Place         Grocery Store                  Bank
# 4            Steakhouse       Thai Restaurant           Coffee Shop
#
#            6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 0                    Salad Place                   Gym          Liquor Store
# 1                       Boutique   Sporting Goods Shop                Museum
# 2               Sushi Restaurant            Restaurant        Sandwich Place
# 3                 Discount Store          Hockey Arena     Convenience Store
# 4  Vegetarian / Vegan Restaurant                   Bar      Sushi Restaurant
#
#   9th Most Common Venue 10th Most Common Venue 11th Most Common Venue
# 0      Asian Restaurant        Thai Restaurant            Supermarket
# 1    Italian Restaurant    American Restaurant                    Gym
# 2    Italian Restaurant           Liquor Store                 Lounge
# 3    Chinese Restaurant   Fast Food Restaurant    Filipino Restaurant
# 4   Japanese Restaurant            Pizza Place       Asian Restaurant

# %% [markdown]
# Show on map

# %%
map_toronto = folium.Map(location=[Toronto_loc[0], Toronto_loc[1]], zoom_start=9)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i+x+(i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(df_merged['lat'], df_merged['lng'], df_merged['Station Name'], df_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_toronto)

# %%
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# 11. Cluster locations using Agglomerative Clustering 5 clusters

# %%
aglo = AgglomerativeClustering(n_clusters=kclusters,linkage='ward').fit(df_grouped_clustering)
aglo.labels_[0:10]
df_merged2 = stat_df.copy()

# add clustering labels
df_merged2['Cluster Labels'] = aglo.labels_

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
df_merged2 = df_merged2.join(neighborhoods_venues_sorted.set_index('Station Name'), on='Station Name')

df_merged2.head() # check the last columns!
# Out:
#                  Station Name        lat        lng Station location  \
# 0     Eglinton Subway Station  43.706716 -79.398298          Midtown
# 1   St. George Subway Station  43.668675 -79.397666         Downtown
# 2  Bloor-Yonge Subway Station  43.670759 -79.385769         Downtown
# 3   Kennedy Subway/RT Station  43.732918 -79.264984           Suburb
# 4      Osgoode Subway Station  43.650877 -79.386824         Downtown
#
#    Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 0               0               Midtown           Coffee Shop
# 1               2              Downtown           Coffee Shop
# 2               0              Downtown           Coffee Shop
# 3               0                Suburb           Coffee Shop
# 4               0              Downtown                  Café
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 0  Fast Food Restaurant                   Pub    Italian Restaurant
# 1            Restaurant        Cosmetics Shop        Sandwich Place
# 2                  Café   Japanese Restaurant           Yoga Studio
# 3        Sandwich Place         Grocery Store                  Bank
# 4            Steakhouse       Thai Restaurant           Coffee Shop
#
#            6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 0                    Salad Place                   Gym          Liquor Store
# 1                       Boutique   Sporting Goods Shop                Museum
# 2               Sushi Restaurant            Restaurant        Sandwich Place
# 3                 Discount Store          Hockey Arena     Convenience Store
# 4  Vegetarian / Vegan Restaurant                   Bar      Sushi Restaurant
#
#   9th Most Common Venue 10th Most Common Venue 11th Most Common Venue
# 0      Asian Restaurant        Thai Restaurant            Supermarket
# 1    Italian Restaurant    American Restaurant                    Gym
# 2    Italian Restaurant           Liquor Store                 Lounge
# 3    Chinese Restaurant   Fast Food Restaurant    Filipino Restaurant
# 4   Japanese Restaurant            Pizza Place       Asian Restaurant

# %% [markdown]
# Show on map

# %%
map_toronto = folium.Map(location=[Toronto_loc[0], Toronto_loc[1]], zoom_start=9)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i+x+(i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(df_merged2['lat'], df_merged2['lng'], df_merged2['Station Name'], df_merged2['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_toronto)

# %%
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# 12. Cluster locations using Affinity Propagation

# %%
af = AffinityPropagation(preference=-0.35).fit(df_grouped_clustering)
cluster_centers_indices = af.cluster_centers_indices_

n_clusters_ = len(cluster_centers_indices)

df_merged3 = stat_df.copy()

# add clustering labels
df_merged3['Cluster Labels'] = af.labels_

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
df_merged3 = df_merged3.join(neighborhoods_venues_sorted.set_index('Station Name'), on='Station Name')

df_merged3.head() # check the last columns!
# Out:
#                  Station Name        lat        lng Station location  \
# 0     Eglinton Subway Station  43.706716 -79.398298          Midtown
# 1   St. George Subway Station  43.668675 -79.397666         Downtown
# 2  Bloor-Yonge Subway Station  43.670759 -79.385769         Downtown
# 3   Kennedy Subway/RT Station  43.732918 -79.264984           Suburb
# 4      Osgoode Subway Station  43.650877 -79.386824         Downtown
#
#    Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 0               0               Midtown           Coffee Shop
# 1               2              Downtown           Coffee Shop
# 2               0              Downtown           Coffee Shop
# 3               0                Suburb           Coffee Shop
# 4               0              Downtown                  Café
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 0  Fast Food Restaurant                   Pub    Italian Restaurant
# 1            Restaurant        Cosmetics Shop        Sandwich Place
# 2                  Café   Japanese Restaurant           Yoga Studio
# 3        Sandwich Place         Grocery Store                  Bank
# 4            Steakhouse       Thai Restaurant           Coffee Shop
#
#            6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 0                    Salad Place                   Gym          Liquor Store
# 1                       Boutique   Sporting Goods Shop                Museum
# 2               Sushi Restaurant            Restaurant        Sandwich Place
# 3                 Discount Store          Hockey Arena     Convenience Store
# 4  Vegetarian / Vegan Restaurant                   Bar      Sushi Restaurant
#
#   9th Most Common Venue 10th Most Common Venue 11th Most Common Venue
# 0      Asian Restaurant        Thai Restaurant            Supermarket
# 1    Italian Restaurant    American Restaurant                    Gym
# 2    Italian Restaurant           Liquor Store                 Lounge
# 3    Chinese Restaurant   Fast Food Restaurant    Filipino Restaurant
# 4   Japanese Restaurant            Pizza Place       Asian Restaurant

# %% [markdown]
# Show on map

# %%
map_toronto = folium.Map(location=[Toronto_loc[0], Toronto_loc[1]], zoom_start=9)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i+x+(i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(df_merged3['lat'], df_merged3['lng'], df_merged3['Station Name'], df_merged3['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_toronto)

# %%
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# 13. Cluster locations using Mean Shift clustering

# %%
bandwidth = estimate_bandwidth(df_grouped_clustering, quantile=0.2, n_samples=50)

db = MeanShift(bandwidth=bandwidth, bin_seeding=True).fit(df_grouped_clustering)

db_labels = db.labels_
#n_clusters_ = (db.core_sample_indices_)

df_merged4 = stat_df.copy()

# add clustering labels
df_merged4['Cluster Labels'] = db.labels_

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
df_merged4 = df_merged4.join(neighborhoods_venues_sorted.set_index('Station Name'), on='Station Name')

df_merged4.head() # check the last columns!
# Out:
#                  Station Name        lat        lng Station location  \
# 0     Eglinton Subway Station  43.706716 -79.398298          Midtown
# 1   St. George Subway Station  43.668675 -79.397666         Downtown
# 2  Bloor-Yonge Subway Station  43.670759 -79.385769         Downtown
# 3   Kennedy Subway/RT Station  43.732918 -79.264984           Suburb
# 4      Osgoode Subway Station  43.650877 -79.386824         Downtown
#
#    Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 0               0               Midtown           Coffee Shop
# 1               1              Downtown           Coffee Shop
# 2               0              Downtown           Coffee Shop
# 3               0                Suburb           Coffee Shop
# 4               0              Downtown                  Café
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 0  Fast Food Restaurant                   Pub    Italian Restaurant
# 1            Restaurant        Cosmetics Shop        Sandwich Place
# 2                  Café   Japanese Restaurant           Yoga Studio
# 3        Sandwich Place         Grocery Store                  Bank
# 4            Steakhouse       Thai Restaurant           Coffee Shop
#
#            6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 0                    Salad Place                   Gym          Liquor Store
# 1                       Boutique   Sporting Goods Shop                Museum
# 2               Sushi Restaurant            Restaurant        Sandwich Place
# 3                 Discount Store          Hockey Arena     Convenience Store
# 4  Vegetarian / Vegan Restaurant                   Bar      Sushi Restaurant
#
#   9th Most Common Venue 10th Most Common Venue 11th Most Common Venue
# 0      Asian Restaurant        Thai Restaurant            Supermarket
# 1    Italian Restaurant    American Restaurant                    Gym
# 2    Italian Restaurant           Liquor Store                 Lounge
# 3    Chinese Restaurant   Fast Food Restaurant    Filipino Restaurant
# 4   Japanese Restaurant            Pizza Place       Asian Restaurant

# %% [markdown]
# Show on map

# %%
map_toronto = folium.Map(location=[Toronto_loc[0], Toronto_loc[1]], zoom_start=9)

x = np.arange(kclusters)
ys = [i+x+(i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(df_merged4['lat'], df_merged4['lng'], df_merged4['Station Name'], df_merged4['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_toronto)

# %%
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# 14. Function to find stations in each results data frame with is in the cluster with more than 5 members and with required venues: Coffee place, Gym/Fitness, Lunch/fast food and Restaurant

# %%
def find_station(df):
    stat_in_cl=[0]*10
    for i in df.index:
        stat_in_cl[df.iloc[i,4]] += 1
    for index, row in df.iterrows():        
        if stat_in_cl[row[4]]>5:
            stat_good=set()
            for j in range(6,16):
                if 'Café' in row[j] or 'Coffee' in row[j]:
                    stat_good.add('coffee')
                if 'Gym' in row[j] or 'Fitness' in row[j] or 'Yoga' in row[j] or 'Pool' in row[j]:
                    stat_good.add('fit')
                if 'Pizza' in row[j] or 'Sandwich' in row[j] or 'Breakfast' in row[j] or 'Salad' in row[j] or 'Burger' in row[j]:
                    stat_good.add('fast')
                if 'Restaurant' in row[j]:
                    stat_good.add('rest')
            if len(stat_good)<4:
                df.drop(index, inplace=True)
        else:
            df.drop(index, inplace=True)
    return(df)

# %% [markdown]
# 15. Run throuh results of each clustering method and prune data frames to contains only stations meeting the criteria

# %%
df_merged=find_station(df_merged)
df_merged.reset_index(inplace=True,drop=True)

df_merged
# Out:
#                    Station Name        lat        lng Station location  \
# 0       Eglinton Subway Station  43.706716 -79.398298          Midtown
# 
Downtown           Coffee Shop
# 2               0              Downtown           Coffee Shop
# 3               0               Midtown           Coffee Shop
# 4               1              Downtown               Gay Bar
# 5               0                Suburb      Greek Restaurant
# 6               0              Downtown           Coffee Shop
# 7               1               Midtown           Coffee Shop
# 8               0               Midtown           Coffee Shop
# 9               1                Suburb           Coffee Shop
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 0  Fast Food Restaurant                   Pub    Italian Restaurant
# 1            Restaurant        Cosmetics Shop        Sandwich Place
# 2                  Café   Japanese Restaurant           Yoga Studio
# 3           Pizza Place                  Bank    Italian Restaurant
# 4   Japanese Restaurant           Coffee Shop          Burger Joint
# 5           Coffee Shop           Pizza Place         Grocery Store
# 6                  Café            Steakhouse    Italian Restaurant
# 7    Italian Restaurant                  Café      Sushi Restaurant
# 8  Caribbean Restaurant    Mexican Restaurant           Yoga Studio
# 9      Sushi Restaurant        Breakfast Spot          Dessert Shop
#
#   6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 0           Salad Place                   Gym          Liquor Store
# 1              Boutique   Sporting Goods Shop                Museum
# 2      Sushi Restaurant            Restaurant        Sandwich Place
# 3      Sushi Restaurant             Gastropub         Deli / Bodega
# 4           Yoga Studio             Nightclub             Gastropub
# 5                   Pub      Sushi Restaurant        Ice Cream Shop
# 6                   Gym   American Restaurant                   Bar
# 7        Sandwich Place           Pizza Place                   Pub
# 8           Pizza Place           Record Shop                  Bank
# 9                   Pub    Italian Restaurant     Indian Restaurant
#
#   9th Most Common Venue 10th Most Common Venue 11th Most Common Venue
# 0      Asian Restaurant        Thai Restaurant            Supermarket
# 1    Italian Restaurant    American Restaurant                    Gym
# 2    Italian Restaurant           Liquor Store                 Lounge
# 3                  Pool         Ice Cream Shop         Cosmetics Shop
# 4         Burrito Place   Ethiopian Restaurant         Breakfast Spot
# 5                   Gym       Ramen Restaurant  Portuguese Restaurant
# 6               Theater             Restaurant            Pizza Place
# 7                   Gym        Thai Restaurant             Bagel Shop
# 8     Convenience Store                 Bakery    Filipino Restaurant
# 9                Bakery            Pizza Place              Pool Hall

# %%
df_merged3=find_station(df_merged3)
df_merged3.reset_index(inplace=True,drop=True)

df_merged3
# Out:
#                    Station Name        lat        lng Station location  \
# 0       Eglinton Subway Station  43.706716 -79.398298          Midtown
# 1     St. George Subway Station  43.668675 -79.397666         Downtown
# 2    Bloor-Yonge Subway Station  43.670759 -79.385769         Downtown
# 3       Lawrence Subway Station  43.725847 -79.402678          Midtown
# 4      Wellesley Subway Station  43.665077 -79.383709         Downtown
# 5           Pape Subway Station  43.680082 -79.344954           Suburb
# 6      St Andrew Subway Station  43.647773 -79.384939         Downtown
# 7       St Clair Subway Station  43.688095 -79.393702          Midtown
# 8  Eglinton West Subway Station  43.699456 -79.436386          Midtown
# 9     Royal York Subway Station  43.648119 -79.511381           Suburb
#
#    Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 0               0               Midtown           Coffee Shop
# 1               2              Downtown           Coffee Shop
# 2               0              Downtown           Coffee Shop
# 3               0               Midtown           Coffee Shop
# 4               3              Downtown               Gay Bar
# 5               0                Suburb      Greek Restaurant
# 6               0              Downtown           Coffee Shop
# 7               3               Midtown           Coffee Shop
# 8               0               Midtown           Coffee Shop
# 9               3                Suburb           Coffee Shop
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 0  Fast Food Restaurant                   Pub    Italian Restaurant
# 1            Restaurant        Cosmetics Shop        Sandwich Place
# 2                  Café   Japanese Restaurant           Yoga Studio
# 3           Pizza Place                  Bank    Italian Restaurant
# 4   Japanese Restaurant           Coffee Shop          Burger Joint
# 5           Coffee Shop           Pizza Place         Grocery Store
# 6                  Café            Steakhouse    Italian Restaurant
# 7    Italian Restaurant                  Café      Sushi Restaurant
# 8  Caribbean Restaurant    Mexican Restaurant           Yoga Studio
# 9      Sushi Restaurant        Breakfast Spot          Dessert Shop
#
#   6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 0           Salad Place                   Gym          Liquor Store
# 1              Boutique   Sporting Goods Shop                Museum
# 2      Sushi Restaurant            Restaurant        Sandwich Place
# 3      Sushi Restaurant             Gastropub         Deli / Bodega
# 4           Yoga Studio             Nightclub             Gastropub
# 5                   Pub      Sushi Restaurant        Ice Cream Shop
# 6                   Gym   American Restaurant                   Bar
# 7        Sandwich Place           Pizza Place                   Pub
# 8           Pizza Place           Record Shop                  Bank
# 9                   Pub    Italian Restaurant     Indian Restaurant
#
#   9th Most Common Venue 10th Most Common Venue 11th Most Common Venue
# 0      Asian Restaurant        Thai Restaurant            Supermarket
# 1    Italian Restaurant    American Restaurant                    Gym
# 2    Italian Restaurant           Liquor Store                 Lounge
# 3                  Pool         Ice Cream Shop         Cosmetics Shop
# 4         Burrito Place   Ethiopian Restaurant         Breakfast Spot
# 5                   Gym       Ramen Restaurant  Portuguese Restaurant
# 6               Theater             Restaurant            Pizza Place
# 7                   Gym        Thai Restaurant             Bagel Shop
# 8     Convenience Store                 Bakery    Filipino Restaurant
# 9                Bakery            Pizza Place              Pool Hall

# %%
df_merged4=find_station(df_merged4)
df_merged4.reset_index(inplace=True,drop=True)

df_merged4
# Out:
#                    Station Name        lat        lng Station location  \
# 0       Eglinton Subway Station  43.706716 -79.398298          Midtown
# 1     St. George Subway Station  43.668675 -79.397666         Downtown
# 2    Bloor-Yonge Subway Station  43.670759 -79.385769         Downtown
# 3       Lawrence Subway Station  43.725847 -79.402678          Midtown
# 4      Wellesley Subway Station  43.665077 -79.383709         Downtown
# 5           Pape Subway Station  43.680082 -79.344954           Suburb
# 6      St Andrew Subway Station  43.647773 -79.384939         Downtown
# 7       St Clair Subway Station  43.688095 -79.393702          Midtown
# 8  Eglinton West Subway Station  43.699456 -79.436386          Midtown
# 9     Royal York Subway Station  43.648119 -79.511381           Suburb
#
#    Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 0               0               Midtown           Coffee Shop
# 1               1              Downtown           Coffee Shop
# 2               0              Downtown           Coffee Shop
# 3               0               Midtown           Coffee Shop
# 4               2              Downtown               Gay Bar
# 5               0                Suburb      Greek Restaurant
# 6               0              Downtown           Coffee Shop
# 7               2               Midtown           Coffee Shop
# 8               0               Midtown           Coffee Shop
# 9               2                Suburb           Coffee Shop
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 0  Fast Food Restaurant                   Pub    Italian Restaurant
# 1            Restaurant        Cosmetics Shop        Sandwich Place
# 2                  Café   Japanese Restaurant           Yoga Studio
# 3           Pizza Place                  Bank    Italian Restaurant
# 4   Japanese Restaurant           Coffee Shop          Burger Joint
# 5           Coffee Shop           Pizza Place         Grocery Store
# 6                  Café            Steakhouse    Italian Restaurant
# 7    Italian Restaurant                  Café      Sushi Restaurant
# 8  Caribbean Restaurant    Mexican Restaurant           Yoga Studio
# 9      Sushi Restaurant        Breakfast Spot          Dessert Shop
#
#   6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 0           Salad Place                   Gym          Liquor Store
# 1              Boutique   Sporting Goods Shop                Museum
# 2      Sushi Restaurant            Restaurant        Sandwich Place
# 3      Sushi Restaurant             Gastropub         Deli / Bodega
# 4           Yoga Studio             Nightclub             Gastropub
# 5                   Pub      Sushi Restaurant        Ice Cream Shop
# 6                   Gym   American Restaurant                   Bar
# 7        Sandwich Place           Pizza Place                   Pub
# 8           Pizza Place           Record Shop                  Bank
# 9                   Pub    Italian Restaurant     Indian Restaurant
#
#   9th Most Common Venue 10th Most Common Venue 11th Most Common Venue
# 0      Asian Restaurant        Thai Restaurant            Supermarket
# 1    Italian Restaurant    American Restaurant                    Gym
# 2    Italian Restaurant           Liquor Store                 Lounge
# 3                  Pool         Ice Cream Shop         Cosmetics Shop
# 4         Burrito Place   Ethiopian Restaurant         Breakfast Spot
# 5                   Gym       Ramen Restaurant  Portuguese Restaurant
# 6               Theater             Restaurant            Pizza Place
# 7                   Gym        Thai Restaurant             Bagel Shop
# 8     Convenience Store                 Bakery    Filipino Restaurant
# 9                Bakery            Pizza Place              Pool Hall

# %% [markdown]
# 16. Since each output contains the same list of stations the final search can be run on one of them

# %% [markdown]
# 17. Add distance of each station from Toronto centre location

# %%
for i in df_merged.index:
    lat_lon = (df_merged.iloc[i,1],df_merged.iloc[i,2])
    df_merged.loc[i,'Distance'] = geopy.distance.vincenty(Toronto_loc, lat_lon ).km

# %% [markdown]
# 18. Score each location taking into account:
#     - number of each relevant venues (0.5 point for each Coffee place, 1 for Fitness, 0.5 for lunch/breakfast/fast food, 1 for Restaurant, 0.25 point for other plances)
#     - use 1/5 of distance in km to divide score - ie. further from centre lower the score
#     - further divide the score by averange cost of office rent in each location category - data used from https://www.statista.com/statistics/802500/asking-rent-per-sf-office-space-toronto-by-submarket/

# %%
for index, row in df_merged.iterrows():        
    stat_good=[]
    for j in range(6,16):
        if 'Café' in row[j] or 'Coffee' in row[j]:
            stat_good.append('coffee')
        if 'Gym' in row[j] or 'Fitness' in row[j] or 'Yoga' in row[j] or 'Pool' in row[j]:
            stat_good.append('fit')
        if 'Pizza' in row[j] or 'Sandwich' in row[j] or 'Breakfast' in row[j] or 'Salad' in row[j] or 'Burger' in row[j]:
            stat_good.append('fast')
        if 'Restaurant' in row[j]:
            stat_good.append('rest')
    score = (0.5*stat_good.count('coffee'))+stat_good.count('fit')+(0.5*stat_good.count('fast')+stat_good.count('rest'))
    score = score + (10-len(stat_good))*0.25
    score = score/(row['Distance']/5)
    if row['Station location']=='Downtown':
        score=score/(30.38*4)
    elif row['Station location']=='Midtown':
        score=score/(23.29*4)
    else:
        score=score/(15.76*4)
    df_merged.loc[index, 'Score']=score

# %% [markdown]
# 19. Provide shortlist of 5 best locations

# %%
df_merged.nlargest(5,'Score')
# Out:
#                  Station Name        lat        lng Station location  \
# 6    St Andrew Subway Station  43.647773 -79.384939         Downtown
# 4    Wellesley Subway Station  43.665077 -79.383709         Downtown
# 2  Bloor-Yonge Subway Station  43.670759 -79.385769         Downtown
# 1   St. George Subway Station  43.668675 -79.397666         Downtown
# 5         Pape Subway Station  43.680082 -79.344954           Suburb
#
#    Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 6               0              Downtown           Coffee Shop
# 4               2              Downtown               Gay Bar
# 2               0              Downtown           Coffee Shop
# 1               1              Downtown           Coffee Shop
# 5               0                Suburb      Greek Restaurant
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 6                  Café            Steakhouse    Italian Restaurant
# 4   Japanese Restaurant           Coffee Shop          Burger Joint
# 2                  Café   Japanese Restaurant           Yoga Studio
# 1            Restaurant        Cosmetics Shop        Sandwich Place
# 5           Coffee Shop           Pizza Place         Grocery Store
#
#   6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 6                   Gym   American Restaurant                   Bar
# 4           Yoga Studio             Nightclub             Gastropub
# 2      Sushi Restaurant            Restaurant        Sandwich Place
# 1              Boutique   Sporting Goods Shop                Museum
# 5                   Pub      Sushi Restaurant        Ice Cream Shop
#
#   9th Most Common Venue 10th Most Common Venue 11th Most Common Venue  \
# 6               Theater             Restaurant            Pizza Place
# 4         Burrito Place   Ethiopian Restaurant         Breakfast Spot
# 2    Italian Restaurant           Liquor Store                 Lounge
# 1    Italian Restaurant    American Restaurant                    Gym
# 5                   Gym       Ramen Restaurant  Portuguese Restaurant
#
#    Distance     Score
# 6  0.711690  0.361336
# 4  1.266635  0.178662
# 2  1.869679  0.154047
# 1  1.839471  0.134209
# 5  4.475966  0.119611
